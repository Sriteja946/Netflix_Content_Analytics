# %%
import pandas as pd
import numpy as np
import sqlalchemy as sal

# %%
df = pd.read_csv("netflix_titles.csv")

# %%
engine = sal.create_engine("mssql+pyodbc://@LAPTOP-DLBO22F9\\SQLEXPRESS/Netflix_Content_Analytics" "?driver=ODBC+Driver+17+for+SQL+Server"
    "&trusted_connection=yes" "&TrustServerCertificate=yes")
conn=engine.connect()
# Out:
# C:\Users\sasri\AppData\Local\Temp\ipykernel_1488\1346782021.py:3: SAWarning: Unrecognized server version info '17.0.1000.7'.  Some SQL Server features may not function properly.
#   conn=engine.connect()

# %%
from sqlalchemy.types import NVARCHAR

# Load the data into sql server
df.to_sql('netflix_raw', con=conn, index=False, if_exists='replace', dtype={'title': NVARCHAR()})
conn.close()

# %%
# df.shape or
len(df)
# Out:
# 8807

# %%
df[df.show_id == 's5023']
# Out:
#      show_id   type    title       director           cast      country  \
# 5022   s5023  Movie  반드시 잡는다  Hong-seon Kim  Baek Yoon-sik  South Korea
#
#              date_added  release_year rating duration  \
# 5022  February 28, 2018          2017  TV-MA  110 min
#
#                                     listed_in  \
# 5022  Dramas, International Movies, Thrillers
#
#                                             description
# 5022  After people in his town start turning up dead...

# %%
# Find the max length of the string for each column

#max(df.show_id.str.len())
#max(df.type.str.len())
#max(df.title.str.len())
#max(df.director.str.len())
#max(df.country.str.len())
#max(df.date_added.str.len())
#####max(df.cast.dropna().str.len())
#max(df.rating.str.len())
#max(df.duration.str.len())
#max(df.listed_in.str.len())
max(df.description.str.len())
# Out:
# 248

# %%
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64
